# %%
import pandas as pd
from nba_api.live.nba.endpoints import scoreboard

# %%
games = scoreboard.ScoreBoard()
games_dict = games.get_dict()
len(games_dict)
# Out:
# 2

# %%
games_dict['meta']
# Out:
# {'version': 1,
#  'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#  'time': '2025-04-11 10:56:41.5641',
#  'code': 200}

# %%
games_dict['scoreboard']['games']
# Out:
# [{'gameId': '0022401167',
#   'gameCode': '20250410/NYKDET',
#   'gameStatus': 3,
#   'gameStatusText': 'Final',
#   'period': 4,
#   'gameClock': '',
#   'gameTimeUTC': '2025-04-10T23:00:00Z',
#   'gameEt': '2025-04-10T19:00:00Z',
#   'regulationPeriods': 4,
#   'ifNecessary': False,
#   'seriesGameNumber': '',
#   'gameLabel': '',
#   'gameSubLabel': '',
#   'seriesText': '',
#   'seriesConference': '',
#   'poRoundDesc': '',
#   'gameSubtype': '',
#   'isNeutral': False,
#   'homeTeam': {'teamId': 1610612765,
#    'teamName': 'Pistons',
#    'teamCity': 'Detroit',
#    'teamTricode': 'DET',
#    'wins': 44,
#    'losses': 36,
#    'score': 115,
#    'seed': None,
#    'inBonus': None,
#    'timeoutsRemaining': 1,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 29},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 27},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 29},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 30}]},
# ...
